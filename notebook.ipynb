# %%
from constructor.db import Collection
from constructor.table import Table
import pandas as pd
import numpy as np # linear algebra
import matplotlib.pyplot as plt
plt.style.use('ggplot')

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import RandomizedSearchCV

from keras.models import Sequential
from keras import layers
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.wrappers.scikit_learn import KerasClassifier

import os
import warnings
warnings.filterwarnings(action='once')

# %% [markdown]
# ## To simulate big data and RAM problems, additional libraries are used.
# Making this mandatory part possible was achieved using Pandas and the PyTables library. The code below initiates a Table class which contains the following functions:
# ```python
# class Table:
#     def __init__(self, csv_file, hdf_file, hdf_key, df_cols_to_index=True):
#         self.csv_file = csv_file
#         self.hdf_file = hdf_file
#         self.hdf_key = hdf_key
#         self.df_cols_to_index = df_cols_to_index
#
#     def store(self):
#         # Delete hdf file if it exists already.
#         if path.exists(self.hdf_file):
#             try:
#                 remove(self.hdf_file)
#             except OSError:
#                 pass
#         store = pd.HDFStore(self.hdf_file)
#         for chunk in pd.read_csv(self.csv_file, chunksize=500000):
#             # don't index data columns in each iteration
#             store.append(self.hdf_key, chunk, data_columns=self.df_cols_to_index, index=False)
#         # index data columns in HDFStore
#         store.create_table_index(self.hdf_key, columns=self.df_cols_to_index, optlevel=9, kind='full')
#         store.close()
#         return store
# ```
#
# Using this function a HDF file is generated based on a CSV-input file which also spawns a DataFrame.

# %%
review_table = Table('hotel-reviews.csv', './data/table.h5', 'hotel_reviews')
review_table.store()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-2840059345b7> in <module>()
#       1 review_table = Table('hotel-reviews.csv', './data/table.h5', 'hotel_reviews')
# ----> 2 review_table.store()
#
# /Users/joost/PycharmProjects/hva-data-scientist/constructor/table.py in store(self)
#      17             except OSError:
#      18                 pass
# ---> 19         store = pd.HDFStore(self.hdf_file)
#      20         for chunk in pd.read_csv(self.csv_file, chunksize=500000):
#      21             # don't index data columns in each iteration
#
# /Users/joost/collector/hva-data-scientist/lib/python3.7/site-packages/pandas/io/pytables.py in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     486         self._fletcher32 = fletcher32
#     487         self._filters = None
# --> 488         self.open(mode=mode, **kwargs)
#     489
#     490     def __fspath__(self):
#
# /Users/joost/collector/hva-data-scientist/lib/python3.7/site-packages/pandas/io/pytables.py in open(self, mode, **kwargs)
#     627                             hdf_version=tables.get_hdf5_version()))
#     628
# --> 629             raise e
#     630
#     631         except (Exception) as e:
#
# /Users/joost/collector/hva-data-scientist/lib/python3.7/site-packages/pandas/io/pytables.py in open(self, mode, **kwargs)
#     601
#     602         try:
# --> 603             self._handle = tables.open_file(self._path, self._mode, **kwargs)
#     604         except (IOError) as e:  # pragma: no cover
#     605             if 'can not be written' in str(e):
#
# /Users/joost/collector/hva-data-scientist/lib/python3.7/site-packages/tables/file.py in open_file(filename, mode, title, root_uep, filters, **kwargs)
#     310                     "The file '%s' is already opened, but "
#     311                     "in read-only mode.  Please close it before "
# --> 312                     "reopening in append mode." % filename)
#     313             # 'w' means that we want to destroy existing contents
#     314             elif mode == 'w':
#
# ValueError: The file './data/table.h5' is already opened, but in read-only mode.  Please close it before reopening in append mode.

# %% [markdown]
# ### Sentiment int, additional field indicating a positive Review 1, or a negative review 0
# To add the sentiment column to the dataframe, it's mandatory to split the positve and negative reviews first. Therefore the reviews are split based on the Reviewer's score. Above 5.4 is positive and below 5.5 is negative. These df's will be concatinated back later on.

# %%
positive = review_table.query('Reviewer_Score > 5.4')
positive['Sentiment'] = 1
negative = review_table.query('Reviewer_Score < 5.5')
negative['Sentiment'] = 0
# Out:
# /Users/joost/collector/hva-data-scientist/lib/python3.7/site-packages/tables/leaf.py:414: PerformanceWarning: The Leaf ``/hotel_reviews/_i_table/Negative_Review/sorted`` is exceeding the maximum recommended rowsize (104857600 bytes);
# be ready to see PyTables asking for *lots* of memory and possibly slow
# I/O.  You may want to reduce the rowsize by trimming the value of
# dimensions that are orthogonal (and preferably close) to the *main*
# dimension of this leave.  Alternatively, in case you have specified a
# very small/large chunksize, you may want to increase/decrease it.
#   PerformanceWarning)
# /Users/joost/collector/hva-data-scientist/lib/python3.7/site-packages/tables/leaf.py:414: PerformanceWarning: The Leaf ``/hotel_reviews/_i_table/Positive_Review/sorted`` is exceeding the maximum recommended rowsize (104857600 bytes);
# be ready to see PyTables asking for *lots* of memory and possibly slow
# I/O.  You may want to reduce the rowsize by trimming the value of
# dimensions that are orthogonal (and preferably close) to the *main*
# dimension of this leave.  Alternatively, in case you have specified a
# very small/large chunksize, you may want to increase/decrease it.
#   PerformanceWarning)

# %% [markdown]
# ### To achieve the requested structure, both the Positive and Negative reviews should be available under Review_Text. Therefore the columns are renamed and the opposite columns will be dropped.

# %%
positive.rename(columns={'Positive_Review': 'Review_Text'}, inplace=True)
positive.drop("Negative_Review", axis=1)
negative.rename(columns={'Negative_Review': 'Review_Text'}, inplace=True)
negative.drop("Positive_Review", axis=1)
# Out:
#                                             Hotel_Address  \
# 0        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 6        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 12       s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 21       s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 22       s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 32       s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 42       s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 44       s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 46       s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 49       s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 60       s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 80       s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 90       s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 92       s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 93       s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 98       s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 100      s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 101      s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 107      s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 120      s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 122      s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 124      s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 134      s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 143      s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 146      s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 147      s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 157      s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 159      s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 162      s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ...                                                   ...
# 515493  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515494  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515502  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515515  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515516  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515517  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515528  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515529  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515537  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515538  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515547  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515551  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515559  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515563  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515579  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515584  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515587  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515595  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515600  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515607  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515621  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515644  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515653  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515661  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515677  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515693  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515700  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515726  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515728  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515735  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                                194    8/3/2017            7.7
# 3                                194   7/31/2017            7.7
# 6                                194   7/17/2017            7.7
# 12                               194    7/6/2017            7.7
# 21                               194   6/12/2017            7.7
# 22                               194   6/10/2017            7.7
# 32                               194   5/11/2017            7.7
# 42                               194   4/14/2017            7.7
# 44                               194    4/5/2017            7.7
# 46                               194    4/5/2017            7.7
# 49                               194   3/22/2017            7.7
# 60                               194    2/6/2017            7.7
# 80                               194  11/15/2016            7.7
# 90                               194  10/24/2016            7.7
# 92                               194  10/12/2016            7.7
# 93                               194  10/11/2016            7.7
# 98                               194   9/19/2016            7.7
# 100                              194   9/18/2016            7.7
# 101                              194   9/12/2016            7.7
# 107                              194   7/26/2016            7.7
# 120                              194    6/5/2016            7.7
# 122                              194    6/1/2016            7.7
# 124                              194   5/22/2016            7.7
# 134                              194    5/1/2016            7.7
# 143                              194   4/19/2016            7.7
# 146                              194   4/12/2016            7.7
# 147                              194    4/7/2016            7.7
# 157                              194   3/12/2016            7.7
# 159                              194    3/1/2016            7.7
# 162                              194   2/29/2016            7.7
# ...                              ...         ...            ...
# 515493                           168  10/21/2016            8.1
# 515494                           168   10/7/2016            8.1
# 515502                           168    9/8/2016            8.1
# 515515                           168   7/26/2016            8.1
# 515516                           168   7/15/2016            8.1
# 515517                           168   7/14/2016            8.1
# 515528                           168   6/18/2016            8.1
# 515529                           168   6/16/2016            8.1
# 515537                           168   5/12/2016            8.1
# 515538                           168   5/10/2016            8.1
# 515547                           168    1/5/2016            8.1
# 515551                           168  10/13/2015            8.1
# 515559                           168   8/24/2015            8.1
# 515563                           168   7/27/2017            8.1
# 515579                           168   6/18/2017            8.1
# 515584                           168    6/5/2017            8.1
# 515587                           168   5/30/2017            8.1
# 515595                           168   5/17/2017            8.1
# 515600                           168    5/1/2017            8.1
# 515607                           168    3/5/2017            8.1
# 515621                           168   1/27/2017            8.1
# 515644                           168  12/10/2016            8.1
# 515653                           168  10/17/2016            8.1
# 515661                           168   9/24/2016            8.1
# 515677                           168   8/19/2016            8.1
# 515693                           168    7/4/2016            8.1
# 515700                           168   5/29/2016            8.1
# 515726                           168   9/28/2015            8.1
# 515728                           168   9/27/2015            8.1
# 515735                           168   8/19/2015            8.1
#
#                    Hotel_Name        Reviewer_Nationality  \
# 0                 Hotel Arena                     Russia
# 3                 Hotel Arena             United Kingdom
# 6                 Hotel Arena             United Kingdom
# 12                Hotel Arena             United Kingdom
# 21                Hotel Arena                     France
# 22                Hotel Arena                    Germany
# 32                Hotel Arena   United States of America
# 42                Hotel Arena                Switzerland
# 44                Hotel Arena   United States of America
# 46                Hotel Arena             United Kingdom
# 49                Hotel Arena       United Arab Emirates
# 60                Hotel Arena                   Malaysia
# 80                Hotel Arena                     Rwanda
# 90                Hotel Arena                     France
# 92                Hotel Arena             United Kingdom
# 93                Hotel Arena                    Finland
# 98                Hotel Arena             United Kingdom
# 100               Hotel Arena             United Kingdom
# 101               Hotel Arena             United Kingdom
# 107               Hotel Arena   United States of America
# 120               Hotel Arena             United Kingdom
# 122               Hotel Arena                 Luxembourg
# 124               Hotel Arena                    Ireland
# 134               Hotel Arena                  Australia
# 143               Hotel Arena                Switzerland
# 146               Hotel Arena             United Kingdom
# 147               Hotel Arena             United Kingdom
# 157               Hotel Arena             United Kingdom
# 159               Hotel Arena                    Finland
# 162               Hotel Arena             United Kingdom
# ...                       ...                         ...
# 515493  Atlantis Hotel Vienna       United Arab Emirates
# 515494  Atlantis Hotel Vienna   United States of America
# 515502  Atlantis Hotel Vienna                     Poland
# 515515  Atlantis Hotel Vienna                    Belgium
# 515516  Atlantis Hotel Vienna   United States of America
# 515517  Atlantis Hotel Vienna                    Hungary
# 515528  Atlantis Hotel Vienna                      India
# 515529  Atlantis Hotel Vienna                     Canada
# 515537  Atlantis Hotel Vienna                    Croatia
# 515538  Atlantis Hotel Vienna                  Australia
# 515547  Atlantis Hotel Vienna                 Luxembourg
# 515551  Atlantis Hotel Vienna                      Italy
# 515559  Atlantis Hotel Vienna                     Latvia
# 515563  Atlantis Hotel Vienna                     Israel
# 515579  Atlantis Hotel Vienna             United Kingdom
# 515584  Atlantis Hotel Vienna                    Croatia
# 515587  Atlantis Hotel Vienna                     Serbia
# 515595  Atlantis Hotel Vienna                  Australia
# 515600  Atlantis Hotel Vienna                Netherlands
# 515607  Atlantis Hotel Vienna                    Belgium
# 515621  Atlantis Hotel Vienna                    Romania
# 515644  Atlantis Hotel Vienna             United Kingdom
# 515653  Atlantis Hotel Vienna                   Slovakia
# 515661  Atlantis Hotel Vienna                     France
# 515677  Atlantis Hotel Vienna                    Germany
# 515693  Atlantis Hotel Vienna       United Arab Emirates
# 515700  Atlantis Hotel Vienna                     Russia
# 515726  Atlantis Hotel Vienna                     Kosovo
# 515728  Atlantis Hotel Vienna                      Qatar
# 515735  Atlantis Hotel Vienna                      Egypt
#
#                                               Review_Text  \
# 0        I am so angry that i made this post available...
# 3        My room was dirty and I was afraid to walk ba...
# 6        Cleaner did not change our sheet and duvet ev...
# 12       The floor in my room was filfy dirty Very bas...
# 21       Our room was an overrated disaster room 231 d...
# 22       Sadly I cannot say that the rooms are clean e...
# 32       Our bathroom had an urine order Shower was ve...
# 42       Hotel is going through a major construction r...
# 44       The service was awful They refused to take ow...
# 46       The hotel is under construction which was nev...
# 49       Service horrible Pillows super stiff and big ...
# 60       The place is completely mismanaged The proper...
# 80       The hotel is being renovated Which means that...
# 90       Even allowing for the hotel being under major...
# 92       In a terrible state with builders everywhere ...
# 93       So lets start from the weird thing that happe...
# 98       Got charged 50 for a birthday package when it...
# 100      Building work starting at 7am waking us up no...
# 101      Hotel is having some construction work done t...
# 107      No Limited A C in common areas Dangerous meta...
# 120      Major construction work underway next door as...
# 122      The bathroom has cristal walls and it is not ...
# 124      The shower was useless and when it worked it ...
# 134      Foyer was a mess Only place to relax was the ...
# 143      The interiors are looking quite tired and the...
# 146      We booked a 3 night stay in a suite On arriva...
# 147      The noise of the construction works that bega...
# 157      The first night we got there we where put in ...
# 159      the hotel was in a bad condition Not really c...
# 162      The room we were given originally wasn t very...
# ...                                                   ...
# 515493   Getting into the room is a nightmare you have...
# 515494   I cannot see why this hotel can be rated with...
# 515502   I had to wait for 20 minuts in the lobby to b...
# 515515   The neighborhood is really not a nice area We...
# 515516   AC was not initially working at all After the...
# 515517   Bored staff loud and non controllable air con...
# 515528   We were kept down the road in another buildin...
# 515529   When we checked in we found out that the air ...
# 515537   It would be OK for 3 star hotel but not for 4...
# 515538   We stayed in a building that was outside the ...
# 515547   No free parking Overpriced breakfast Not conv...
# 515551   very bad experience After I left the hotel I ...
# 515559   First we ve got a room where still were some ...
# 515563   There was no internet connection The telephon...
# 515579   The district no pavement cafes Unfriendly Res...
# 515584                 Unpleaseant staff at the reception
# 515587   Weird hotel layout maybe because of ongoing r...
# 515595     8am wake up from hotel repairs very rude staff
# 515600     Rooms were too hot and the hotel didnot had AC
# 515607           I couldn t sleep because it s too noisy
# 515621             The room was vert small not a 4 hotel
# 515644   All beds are twin beds basically and it is de...
# 515653   Completely uncomfortable bed noise on the str...
# 515661   Can t even stop the car to unload in front of...
# 515677                Being 4star hotel except breakfast
# 515693   Since there is no room service they should pr...
# 515700   Room vas located in different building with n...
# 515726   They put other fotos and cinde of rooms to se...
# 515728                                         Everything
# 515735   The ac was useless It was a hot week in vienn...
#
#         Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 0                                     397                     1403
# 3                                     210                     1403
# 6                                      33                     1403
# 12                                     28                     1403
# 21                                     92                     1403
# 22                                    364                     1403
# 32                                     68                     1403
# 42                                    110                     1403
# 44                                     26                     1403
# 46                                    315                     1403
# 49                                     53                     1403
# 60                                    144                     1403
# 80                                     37                     1403
# 90                                    119                     1403
# 92                                     42                     1403
# 93                                    264                     1403
# 98                                    112                     1403
# 100                                    40                     1403
# 101                                    56                     1403
# 107                                    52                     1403
# 120                                    75                     1403
# 122                                    21                     1403
# 124                                   126                     1403
# 134                                   180                     1403
# 143                                    36                     1403
# 146                                   195                     1403
# 147                                    29                     1403
# 157                                   145                     1403
# 159                                    44                     1403
# 162                                    51                     1403
# ...                                   ...                      ...
# 515493                                 55                     2823
# 515494                                 97                     2823
# 515502                                 63                     2823
# 515515                                 64                     2823
# 515516                                 25                     2823
# 515517                                 26                     2823
# 515528                                121                     2823
# 515529                                102                     2823
# 515537                                 41                     2823
# 515538                                 71                     2823
# 515547                                132                     2823
# 515551                                 51                     2823
# 515559                                 44                     2823
# 515563                                 23                     2823
# 515579                                 15                     2823
# 515584                                  6                     2823
# 515587                                 21                     2823
# 515595                                 10                     2823
# 515600                                 11                     2823
# 515607                                 11                     2823
# 515621                                 11                     2823
# 515644                                 23                     2823
# 515653                                 21                     2823
# 515661                                 23                     2823
# 515677                                  7                     2823
# 515693                                 18                     2823
# 515700                                 25                     2823
# 515726                                 21                     2823
# 515728                                  2                     2823
# 515735                                 19                     2823
#
#         Review_Total_Positive_Word_Counts  \
# 0                                      11
# 3                                      26
# 6                                      18
# 12                                      6
# 21                                     75
# 22                                     37
# 32                                      0
# 42                                     15
# 44                                     11
# 46                                      3
# 49                                      4
# 60                                      5
# 80                                     18
# 90                                      4
# 92                                      5
# 93                                     81
# 98                                      0
# 100                                     2
# 101                                    28
# 107                                     6
# 120                                    36
# 122                                    12
# 124                                     6
# 134                                     0
# 143                                    19
# 146                                     0
# 147                                    15
# 157                                    94
# 159                                     5
# 162                                     8
# ...                                   ...
# 515493                                  7
# 515494                                  0
# 515502                                  8
# 515515                                 11
# 515516                                  9
# 515517                                  5
# 515528                                  4
# 515529                                  0
# 515537                                  2
# 515538                                 13
# 515547                                  8
# 515551                                  0
# 515559                                 33
# 515563                                  0
# 515579                                  9
# 515584                                  0
# 515587                                  5
# 515595                                 12
# 515600                                  0
# 515607                                  0
# 515621                                  0
# 515644                                  7
# 515653                                  0
# 515661                                  0
# 515677                                  2
# 515693                                  5
# 515700                                  0
# 515726                                  5
# 515728                                  2
# 515735                                  0
#
#         Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 0                                                7             2.9
# 3                                                1             3.8
# 6                                                6             4.6
# 12                                               7             4.6
# 21                                              12             3.8
# 22                                              21             5.4
# 32                                               1             4.2
# 42                                               4             2.9
# 44                                               1             3.3
# 46                                               7             4.2
# 49                                               2             5.4
# 60                                               6             4.6
# 80                                              10             5.4
# 90                                              21             4.2
# 92                                               1             5.0
# 93                                              16             4.2
# 98                                               1             5.0
# 100                                              1             5.0
# 101                                              5             4.6
# 107                                              1             3.8
# 120                                              2             4.6
# 122                                              9             4.2
# 124                                              2             4.6
# 134                                              6             4.6
# 143                                             16             5.4
# 146                                              1             2.5
# 147                                              5             5.4
# 157                                              1             5.0
# 159                                              1             4.2
# 162                                              1             5.0
# ...                                            ...             ...
# 515493                                           8             3.8
# 515494                                           1             4.2
# 515502                                           4             5.0
# 515515                                           1             5.0
# 515516                                           3             5.0
# 515517                                          14             3.3
# 515528                                           9             3.8
# 515529                                           3             3.3
# 515537                                           7             4.6
# 515538                                           4             4.6
# 515547                                          31             5.0
# 515551                                           3             4.6
# 515559                                           7             4.2
# 515563                                           3             4.6
# 515579                                           8             3.8
# 515584                                           2             5.0
# 515587                                           3             5.4
# 515595                                           6             2.9
# 515600                                           9             4.6
# 515607                                           6             4.2
# 515621                                           9             4.2
# 515644                                           7             5.4
# 515653                                          33             5.4
# 515661                                           6             3.8
# 515677                                          11             3.8
# 515693                                           7             5.0
# 515700                                           2             3.8
# 515726                                          34             5.4
# 515728                                           1             4.2
# 515735                                           3             2.5
#
#                                                      Tags days_since_review  \
# 0       [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 3       [' Leisure trip ', ' Solo traveler ', ' Duplex...            3 days
# 6       [' Leisure trip ', ' Group ', ' Duplex Twin Ro...           17 days
# 12      [' Leisure trip ', ' Solo traveler ', ' Duplex...           28 days
# 21      [' Couple ', ' Duplex Double Room ', ' Stayed ...           52 days
# 22      [' Leisure trip ', ' Family with young childre...           54 days
# 32      [' Leisure trip ', ' Group ', ' Duplex Twin Ro...           84 days
# 42      [' Business trip ', ' Solo traveler ', ' Large...           111 day
# 44      [' Leisure trip ', ' Group ', ' Large King Roo...           120 day
# 46      [' Leisure trip ', ' Couple ', ' Duplex Double...           120 day
# 49      [' Business trip ', ' Couple ', ' Large King R...           134 day
# 60      [' Leisure trip ', ' Group ', ' Duplex Twin Ro...           178 day
# 80      [' Leisure trip ', ' Couple ', ' Suite ', ' St...           261 day
# 90      [' Leisure trip ', ' Couple ', ' Large King Ro...           283 day
# 92      [' Business trip ', ' Couple ', ' Duplex Doubl...           295 day
# 93      [' Leisure trip ', ' Group ', ' Duplex Twin Ro...           296 day
# 98      [' Leisure trip ', ' Couple ', ' Large King Ro...           318 day
# 100     [' Leisure trip ', ' Group ', ' Duplex Double ...           319 day
# 101     [' Business trip ', ' Solo traveler ', ' Duple...           325 day
# 107     [' Business trip ', ' Couple ', ' Duplex Doubl...           373 day
# 120     [' Leisure trip ', ' Couple ', ' Duplex Double...           424 day
# 122     [' Leisure trip ', ' Couple ', ' Duplex Double...           428 day
# 124     [' Leisure trip ', ' Couple ', ' Duplex Double...           438 day
# 134     [' Leisure trip ', ' Couple ', ' Duplex Double...           459 day
# 143     [' Leisure trip ', ' Couple ', ' Duplex Double...           471 day
# 146     [' Leisure trip ', ' Couple ', ' Suite ', ' St...           478 day
# 147     [' Leisure trip ', ' Couple ', ' Duplex Double...           483 day
# 157     [' Leisure trip ', ' Couple ', ' Duplex Double...           509 day
# 159     [' Leisure trip ', ' Solo traveler ', ' Duplex...           520 day
# 162     [' Leisure trip ', ' Couple ', ' Duplex Double...           521 day
# ...                                                   ...               ...
# 515493  [' Leisure trip ', ' Family with young childre...           286 day
# 515494  [' Business trip ', ' Solo traveler ', ' Stand...           300 day
# 515502  [' Leisure trip ', ' Family with young childre...           329 day
# 515515  [' Leisure trip ', ' Family with older childre...           373 day
# 515516  [' Leisure trip ', ' Family with older childre...           384 day
# 515517  [' Leisure trip ', ' Couple ', ' Standard Doub...           385 day
# 515528  [' Leisure trip ', ' Couple ', ' Standard Doub...           411 day
# 515529  [' Leisure trip ', ' Family with older childre...           413 day
# 515537  [' Leisure trip ', ' Couple ', ' Standard Doub...           448 day
# 515538  [' Leisure trip ', ' Family with older childre...           450 day
# 515547  [' With a pet ', ' Leisure trip ', ' Couple ',...           576 day
# 515551  [' Leisure trip ', ' Family with young childre...           660 day
# 515559  [' Leisure trip ', ' Couple ', ' Standard Doub...           710 day
# 515563  [' Leisure trip ', ' Group ', ' Family Room ',...            7 days
# 515579  [' Leisure trip ', ' Family with young childre...           46 days
# 515584  [' Leisure trip ', ' Family with young childre...           59 days
# 515587  [' Business trip ', ' Couple ', ' Standard Dou...           65 days
# 515595  [' Business trip ', ' Group ', ' Standard Trip...           78 days
# 515600  [' Business trip ', ' Group ', ' Standard Doub...           94 days
# 515607  [' Leisure trip ', ' Family with young childre...           151 day
# 515621  [' Leisure trip ', ' Solo traveler ', ' Standa...           188 day
# 515644  [' Leisure trip ', ' Couple ', ' Standard Doub...           236 day
# 515653  [' Leisure trip ', ' Couple ', ' Standard Doub...           290 day
# 515661  [' Leisure trip ', ' Family with young childre...           313 day
# 515677  [' Leisure trip ', ' Family with older childre...           349 day
# 515693  [' Leisure trip ', ' Couple ', ' Standard Doub...           395 day
# 515700  [' Business trip ', ' Solo traveler ', ' Stand...           431 day
# 515726  [' Business trip ', ' Couple ', ' Standard Dou...           675 day
# 515728  [' Leisure trip ', ' Couple ', ' Standard Doub...           676 day
# 515735  [' Leisure trip ', ' Family with older childre...           715 day
#
#               lat        lng  Sentiment
# 0       52.360576   4.915968          0
# 3       52.360576   4.915968          0
# 6       52.360576   4.915968          0
# 12      52.360576   4.915968          0
# 21      52.360576   4.915968          0
# 22      52.360576   4.915968          0
# 32      52.360576   4.915968          0
# 42      52.360576   4.915968          0
# 44      52.360576   4.915968          0
# 46      52.360576   4.915968          0
# 49      52.360576   4.915968          0
# 60      52.360576   4.915968          0
# 80      52.360576   4.915968          0
# 90      52.360576   4.915968          0
# 92      52.360576   4.915968          0
# 93      52.360576   4.915968          0
# 98      52.360576   4.915968          0
# 100     52.360576   4.915968          0
# 101     52.360576   4.915968          0
# 107     52.360576   4.915968          0
# 120     52.360576   4.915968          0
# 122     52.360576   4.915968          0
# 124     52.360576   4.915968          0
# 134     52.360576   4.915968          0
# 143     52.360576   4.915968          0
# 146     52.360576   4.915968          0
# 147     52.360576   4.915968          0
# 157     52.360576   4.915968          0
# 159     52.360576   4.915968          0
# 162     52.360576   4.915968          0
# ...           ...        ...        ...
# 515493  48.203745  16.335677          0
# 515494  48.203745  16.335677          0
# 515502  48.203745  16.335677          0
# 515515  48.203745  16.335677          0
# 515516  48.203745  16.335677          0
# 515517  48.203745  16.335677          0
# 515528  48.203745  16.335677          0
# 515529  48.203745  16.335677          0
# 515537  48.203745  16.335677          0
# 515538  48.203745  16.335677          0
# 515547  48.203745  16.335677          0
# 515551  48.203745  16.335677          0
# 515559  48.203745  16.335677          0
# 515563  48.203745  16.335677          0
# 515579  48.203745  16.335677          0
# 515584  48.203745  16.335677          0
# 515587  48.203745  16.335677          0
# 515595  48.203745  16.335677          0
# 515600  48.203745  16.335677          0
# 515607  48.203745  16.335677          0
# 515621  48.203745  16.335677          0
# 515644  48.203745  16.335677          0
# 515653  48.203745  16.335677          0
# 515661  48.203745  16.335677          0
# 515677  48.203745  16.335677          0
# 515693  48.203745  16.335677          0
# 515700  48.203745  16.335677          0
# 515726  48.203745  16.335677          0
# 515728  48.203745  16.335677          0
# 515735  48.203745  16.335677          0
#
# [40229 rows x 17 columns]

# %% [markdown]
# ### After some initial selection cleaning the result should be written away as a Review_pos.csv and Review_neg.csv
# Below code will transform the postive and negative df's to a CSV-file.

# %%
positive.to_csv(r'./data/Review_pos.csv', index=None, header=True)
negative.to_csv(r'./data/Review_neg.csv', index=None, header=True)

# %% [markdown]
# As told earlier, the dataframes need to be concatinated back together to from a complete df including the sentiment values.

# %%
df = pd.concat([positive, negative], sort=False)

# %% [markdown]
# ### There should be a collection of balanced set of reviews, for instance a collection consisting of 10.000 positive and 10.000 negative reviews having a least the following structure
# * Review
# * Sentiment
#
# Code below samples the positive and negative collections with 10K records each. These and the full collection will be filled into the MongoDB instance using the Collection class:
# ```python
# class Collection:
#     def __init__(self, df, collection):
#         self.client = MongoClient('mongodb://localhost:27017')  # Init mongoclient
#         self.db = self.client['assignment-2']  # Assign db name
#         self.df = df
#         self.collection = collection
#         self.conn = self.db[self.collection]
#
#     def fill(self):
#         dict = self.df.to_dict(orient='records')
#         self.conn.delete_many({ })    # Clear collection using an empty filter.
#         self.conn.insert_many(dict)
# ```

# %%
Collection(df, 'hotel-reviews').fill()    # Fill mongo with complete df
Collection(positive[['Review_Text', 'Sentiment']].sample(n=10000), 'pos').fill()
Collection(negative[['Review_Text', 'Sentiment']].sample(n=10000), 'neg').fill()
